# %% [markdown]
# #Quantum Assisted Gaussian Process (QGP) Simulations
#
# This work book endeavours to simular Quantum Assisted Gaussian Processes (http://arxiv.org/abs/1512.03929). The code simulates the variance induced by the quantum system when using naturally sparse kernels.

# %%
import sys
import os
import numpy as np
# %pylab inline
import matplotlib.pyplot as plt
import pyGPs
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Kernels
#
# We will use three kernels which lead to sparse covariance matrices. The first is from [MacKay](http://www.inference.eng.cam.ac.uk/mackay/gp.pdf):
#
# $k(x,x')= 1 - |x-'x|/d,$ if $|x-'x|<d$
#
# $k(x,x')= 0,$ otherwise
#
# The second is from [Storkey](https://www.researchgate.net/profile/Amos_Storkey/publication/3835514_Truncated_covariance_matrices_and_Toeplitz_methods_in_Gaussian_processes/links/02bfe5120657a2b20f000000.pdf):
#
# $k(x,x')= 1 + cos(|x-'x|/d),$ if $|x-'x|/d<\pi$
#
# $k(x,x')= 0,$ otherwise
#
# Finally, the third is from [Melkumyan](https://www.aaai.org/ocs/index.php/IJCAI/IJCAI-09/paper/viewFile/630/840):
#
# $k(x,x')= \frac{1 - cos(2\pi \frac{|x-'x|}{d})}{3}(1 - \frac{|x-'x|}{d}) + \frac{1}{2\pi}sin(2\pi \frac{|x-'x|}{d}),$ if $|x-'x|<d$
#
# $k(x,x')= 0,$ otherwise
#
# The latter two kernels have very similar properties to the gaussian kernel (also known as the square exponential or rbf kernel).
#
# Each of these kernels may be multiplied by a constant $\sigma^2$ which can be optimised during training. We also note that adding i.i.d. noise does not effect the sparsity. This noise $\sigma_n^2$ will also be optimised.

# %%
# Define the kernel functions

import scipy.spatial.distance as spdist

class kernel_mackay(pyGPs.Core.cov.Kernel):
    '''
    MacKay kernel with isotropic distance measure. hyp = [log_ell, log_sigma]
    :param log_ell: characteristic length scale.
    :param log_sigma: signal deviation.
    '''
    def __init__(self, D=12, log_ell=0., log_sigma=0.):
        self.hyp = [0. for i in range(D)] + [log_sigma]


    def getCovMatrix(self,x=None,z=None,mode=None):
        #self.checkInputGetCovMatrix(x,z,mode)
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        ell = np.exp(self.hyp[0:D])*2         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for training set
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
        A[A>1] = 1.
        A = sf2 *(1. - A)
        return A


    def getDerMatrix(self,x=None,z=None,mode=None,der=None):
        #self.checkInputGetDerMatrix(x,z,mode,der)
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        ell = np.exp(self.hyp[0:D])*2         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for dataset x
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
                
        if der < D:    # compute derivative matrix wrt 1st parameter
            A[A>1] = 0.
            A = sf2 * A / ell[der]
        elif der == D:  # compute derivative matrix wrt 2nd parameter
            A[A>1] = 1.
            A = 2. * sf2 *(1. - A)
        else:
            raise Exception("Calling for a derivative in MacKay kernel that does not exist")
        return A

class kernel_storkey(pyGPs.Core.cov.Kernel):
    '''
    Storkey kernel with isotropic distance measure. hyp = [log_ell, log_sigma]
    :param log_ell: characteristic length scale.
    :param log_sigma: signal deviation.
    '''
    def __init__(self, D=12, log_ell=0., log_sigma=0.):
        self.hyp = [0. for i in range(D)] + [log_sigma]

    def getCovMatrix(self,x=None,z=None,mode=None):
        #self.checkInputGetCovMatrix(x,z,mode)
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        ell = np.exp(self.hyp[0:D])         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for training set
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
        A[A>np.pi] = np.pi
        A = sf2 *(1. + np.cos(A))
        return A


    def getDerMatrix(self,x=None,z=None,mode=None,der=None):
        #self.checkInputGetDerMatrix(x,z,mode,der)
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        ell = np.exp(self.hyp[0:D])         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for dataset x
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
        
        if der < D:    # compute derivative matrix wrt 1st parameter
            A[A>np.pi] = 0.
            A = sf2 * A*sin(A)/ell[der]
        elif der == D:  # compute derivative matrix wrt 2nd parameter
            A[A>np.pi] = np.pi
            A = 2. * sf2 *(1. + np.cos(A))
        else:
            raise Exception("Calling for a derivative in Storkey kernel that does not exist")
        return A
    
class kernel_melkumyan(pyGPs.Core.cov.Kernel):
    '''
    Melkumyan kernel with isotropic distance measure. hyp = [log_ell, log_sigma]
    :param log_ell: characteristic length scale.
    :param log_sigma: signal deviation.
    '''
    def __init__(self, D=12, log_ell=0., log_sigma=0.):
        self.hyp = [0. for i in range(D)] + [log_sigma]

    def getCovMatrix(self,x=None,z=None,mode=None):
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        #self.checkInputGetCovMatrix(x,z,mode)
        ell = np.exp(self.hyp[0:D])*3         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for training set
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
        idx = np.where(A>=1.)
        A = sf2 *(((2 + np.cos(2*np.pi*A))*(1 - A)/3) + np.sin(2*np.pi*A)/(2*np.pi))
        A[idx] = 0.
        return A


    def getDerMatrix(self,x=None,z=None,mode=None,der=None):
        #self.checkInputGetDerMatrix(x,z,mode,der)
        if not x is None:
            n, D = x.shape
        if not z is None:
            nn, D = z.shape
        ell = np.exp(self.hyp[0:D])         # characteristic length scale
        sf2 = np.exp(2.*self.hyp[D])      # signal variance
        if mode == 'self_test':           # self covariances for the test cases
            nn,D = z.shape
            A = np.zeros((nn,1))
        elif mode == 'train':             # compute covariance matix for dataset x
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),x.T).T,'euclidean')
        elif mode == 'cross':             # compute covariance between data sets x and z
            A = spdist.cdist(np.dot(np.diag(1/ell),x.T).T,np.dot(np.diag(1/ell),z.T).T,'euclidean')
        
        if der < D:    # compute derivative matrix wrt 1st parameter
            idx = np.where(A>=1.)
             #-(4 d sin((pi d)/x) (pi (d-x) cos((pi d)/x)-x sin((pi d)/x)))/(3 x^3)
            A = sf2 * (-1) * (4*(A*ell[der])*sin(np.pi*A)*(np.pi*ell[der]*(A-1)*cos(np.pi*A)-ell[der]*sin(np.pi*A)))/(3*ell[der]**3)
            A[idx] = 0.
        elif der == D:  # compute derivative matrix wrt 2nd parameter
            idx = np.where(A>=1.)
            A = 2 * sf2 *(((2 + np.cos(2*np.pi*A))*(1 - A)/3) + np.sin(2*np.pi*A)/(2*np.pi))
            A[idx] = 0.
        else:
            raise Exception("Calling for a derivative in Melkumyan kernel that does not exist")
        return A
    
# Plot the kernels so we can see what we are working with

X = np.linspace(0, 10, 100).reshape(-1,1)

K_mackay = kernel_mackay(D=1)
K_storkey = kernel_storkey(D=1)
K_melkumyan = kernel_melkumyan(D=1)

K1 = K_mackay.getCovMatrix(X, mode='train')
K2 = K_storkey.getCovMatrix(X, mode='train')
K3 = K_melkumyan.getCovMatrix(X, mode='train')

f, (axa, axb, axc) = plt.subplots(1,3, sharex=True, sharey=True, figsize=[15,4.5])

axa.imshow(K1)
axa.set_title('Covariance Matrix from MacKay Kernel')

axb.imshow(K2)
axb.set_title('Covariance Matrix from Storkey Kernel')

axc.imshow(K3)
axc.set_title('Covariance Matrix from Melkumyan Kernel')

# Plot some draws from their function spaces

f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True, figsize=[15,10])

for r in range(40):
    f = np.random.multivariate_normal(np.zeros(100), K1)
    ax1.plot(X, f, 'b', linewidth=1, label='$f(t)$' if r==0 else None, alpha=0.05)
f = np.random.multivariate_normal(np.zeros(100), K1)
ax1.plot(X, f, 'r', linewidth=1.5, alpha=0.8)
ax1.set_title('Draws from a MacKay Kernel')
ax1.set_xlabel('Input (x)')
ax1.set_ylabel('Output (f(x))')
for r in range(40):
    f = np.random.multivariate_normal(np.zeros(100), K2)
    ax2.plot(X, f, 'b', linewidth=1, label='$f(t)$' if r==0 else None, alpha=0.05)
f = np.random.multivariate_normal(np.zeros(100), K2)
ax2.plot(X, f, 'r', linewidth=1.5, alpha=0.8)
ax2.set_title('Draws from a Storkey Kernel')
ax2.set_xlabel('Input (x)')
ax2.set_ylabel('Output (f(x))')
for r in range(40):
    f = np.random.multivariate_normal(np.zeros(100), K3)
    ax3.plot(X, f, 'b', linewidth=1, label='$f(t)$' if r==0 else None, alpha=0.05)
f = np.random.multivariate_normal(np.zeros(100), K3)
ax3.plot(X, f, 'r', linewidth=1.5, alpha=0.8)
ax3.set_title('Draws from a Melkumyan Kernel')
ax3.set_xlabel('Input (x)')
ax3.set_ylabel('Output (f(x))')
# Out:
#  /Library/Python/2.7/site-packages/IPython/kernel/__main__.py:211: RuntimeWarning:covariance is not positive-semidefinite.
#  /Library/Python/2.7/site-packages/IPython/kernel/__main__.py:213: RuntimeWarning:covariance is not positive-semidefinite.

# %% [markdown]
# ## Datasets (Large Scale)
#
# We will check out three datasets where we might expect GPs using the above functions to model the data reasonably well.
#
# ### Property Dataset
# ### Airplane Dataset
# ### Land Altitude Dataset
#
# While it is not feasible to compute the exact Gaussian processon these datasets, we can measure the level of sparsity in the covariance matrices. Note that when we refer to sparse matrices in this context we are talking about the fraaction of elements which are equal to zero as opposed to the more common low rank meaning in the Gaussian process community.

# %%
# Set up

for i in xrange(3):
    # Load in Dataset

    # For compute the level of sparsity 

    # Print output
    print '...'

# %% [markdown]
# ## Datasets (Small)
#
# Now we will use small datasets (~10^4 observations) with which we can actually compute the exact Gaussian process and simulate the variance intoduced by the quantum computation. While these datasets are generally quite small, hopefully they will give us an indication of usefulness of QGPs.
#
# ### Housing Dataset

# %% [markdown]
# ## QGP Simulation and Analytic Performance Bounds
#
# In the code below we compute the exact GP, the analytic bound we derived for the QGP and a simulation which draws from the Bernoulli distibution to simulate the measurements of <M> in the QGP.

# %%
infile = 'datasets/small/housing.txt'
data = np.genfromtxt(infile)

DN, DD = data.shape
N = 25
# Get all data (exclude the 4th column which is binary) except the last 50 points for training
x  = np.concatenate((data[:-N,:4],data[:-N,5:-1]),axis=1)
x = (x - np.mean(x,axis=0))/(np.std(x,axis=0)+1.e-16)
# The function we will perform regression on:  Median Value of owner occupied homes
y  = np.reshape(data[:-N,-1],(len(data[:-N,-1]),1))
my = np.mean(y)
sy = np.std(y)
y = (y-np.mean(y))/(np.std(y)+1.e-16)
y[np.abs(y)<0.025] = 0
# Test on the last 50 points
xs  = np.concatenate((data[-N:,:4],data[-N:,5:-1]),axis=1)
xs = (xs - np.mean(xs,axis=0))/(np.std(xs,axis=0)+1.e-16)
ys = np.reshape(data[-N:,-1],(N,1))
ys = (ys-my)/(sy+1.e-16)
N,D = x.shape

print 'Housing Dataset Dim:', N, 'by', D

V = []
M = []
C = []
optHyp = []

for kernel_type in xrange(3):
    model = pyGPs.GPR()
    if kernel_type == 0:
        model.setPrior(kernel=kernel_mackay()+pyGPs.cov.Noise())
    elif kernel_type == 1:
        model.setPrior(kernel=kernel_storkey()+pyGPs.cov.Noise())
    else:
        model.setPrior(kernel=kernel_melkumyan()+pyGPs.cov.Noise())
    model.getPosterior(x, y)
    print('Initial negative log marginal likelihood = ', round(model.nlZ,3))

    # train and predict
    from time import clock
    t0 = clock()
    model.optimize(x,y)
    t1 = clock()
    ym, ys2, fm, fs2, lp = model.predict(xs)
    xa  = np.concatenate((data[:,:4],data[:,5:-1]),axis=1)
    xa = (xa - np.mean(xa,axis=0))/(np.std(xa,axis=0)+1.e-16)
    ya, ys2a, fma, fs2a, lpa = model.predict(xa)

    print('Time to optimize = ', t1-t0)
    print('Optimized mean = ', model.meanfunc.hyp)
    print('Optimized covariance = ', model.covfunc.hyp)
    print('Optimized liklihood = ', model.likfunc.hyp)
    print('Final negative log marginal likelihood = ', round(model.nlZ,3))
    print('Kernel Sparsity = ', np.mean(model.covfunc.getCovMatrix(x, xs, mode='cross')>0))
    print('Observation Sparsity = ', np.mean(y!=0))
    
    optHyp.append([model.meanfunc.hyp, model.covfunc.hyp, model.likfunc.hyp])
    
    cy = np.abs(y).max()**-1
    ck = np.abs(model.covfunc.getCovMatrix(x, xs, mode='cross')).max()**-1
    sy = np.sum(y!=0)
    sk = np.sum(model.covfunc.getCovMatrix(x, xs, mode='cross')!=0)
    sn = np.exp(model.covfunc.cov2.hyp[0]*2)
    
    C.append([np.sqrt(sy*sk)/(sn*ck*cy)]/np.mean(ys2))
    #V.append(ys2)
    #M.append(ym)
    
    #HousingPlotter(range(len(y)),y,range(len(ym)),ym,ys2,range(len(y),len(y)+len(ys)),ys)
    xm = np.array(list(range(len(y),len(y)+ym.shape[0])))
    ym = np.reshape(ym,(ym.shape[0],))
    zm = np.reshape(ys2,(ym.shape[0],))

    plt.figure(figsize=[15,10])

    plt.plot(ya,'g')
    plt.fill_between(xm, ym + 1.*np.sqrt(zm), ym - 1.*np.sqrt(zm), facecolor=[0.,1.0,0.0,0.9],linewidths=0.0)
    plt.fill_between(xm, ym + 2.*np.sqrt(zm), ym - 2.*np.sqrt(zm), facecolor=[0.,1.0,0.0,0.5],linewidths=0.0)
    plt.fill_between(xm, ym + 3.*np.sqrt(zm), ym - 3.*np.sqrt(zm), facecolor=[0.,1.0,0.0,0.1],linewidths=0.0)

    plt.plot(y,'r.',linewidth = 3.0, markersize = 5.0)
    plt.plot(xm,ym[-N:], 'bx', linewidth = 3.0, markersize = 5.0)
    plt.grid()
    if kernel_type == 0:
        plt.title('MacKay Kernel')
    elif kernel_type == 1:
        plt.title('Storkey Kernel')
    else:
        plt.title('Melkumyan Kernel')
    plt.xlabel('Index')
    plt.ylabel('Median Home Values (normalized)')
    plt.axis([0.,510.,-3.5,3.5])
# Out:
# Housing Dataset Dim: 481 by 12
# ('Initial negative log marginal likelihood = ', 635.609)
# Warning: adding jitter of 1.0238471808e-04
# Warning: adding jitter of 1.0238471808e-03
# Warning: adding jitter of 1.0238471808e-02
# Warning: adding jitter of 1.0238471808e-01
# Warning: adding jitter of 1.0238471808e+00
# Warning: adding jitter of 7.7356126428e-05
# Warning: adding jitter of 7.7356126428e-04
# Warning: adding jitter of 7.7356126428e-03
# Warning: adding jitter of 7.7356126428e-02
# Warning: adding jitter of 7.7356126428e-01
# Warning: adding jitter of 5.3648639985e-05
# Warning: adding jitter of 5.3648639985e-04
# Warning: adding jitter of 5.3648639985e-03
# Warning: adding jitter of 5.3648639985e-02
# Warning: adding jitter of 5.3648639985e-01
# Warning: adding jitter of 9.5151446953e-05
# Warning: adding jitter of 9.5151446953e-04
# Warning: adding jitter of 9.5151446953e-03
# Warning: adding jitter of 9.5151446953e-02
# Warning: adding jitter of 9.5151446953e-01
# Warning: adding jitter of 7.0206279457e-05
# Warning: adding jitter of 7.0206279457e-04
# Warning: adding jitter of 7.0206279457e-03
# Warning: adding jitter of 7.0206279457e-02
# Warning: adding jitter of 7.0206279457e-01
# Warning: adding jitter of 4.7382454443e-05
# Warning: adding jitter of 4.7382454443e-04
# Warning: adding jitter of 4.7382454443e-03
# Warning: adding jitter of 4.7382454443e-02
# Warning: adding jitter of 4.7382454443e-01
# Warning: adding jitter of 8.7852449920e-05
# Warning: adding jitter of 8.7852449920e-04
# Warning: adding jitter of 8.7852449920e-03
# Warning: adding jitter of 8.7852449920e-02
# Warning: adding jitter of 8.7852449920e-01
# Warning: adding jitter of 6.3241917655e-05
# Warning: adding jitter of 6.3241917655e-04
# Warning: adding jitter of 6.3241917655e-03
# Warning: adding jitter of 6.3241917655e-02
# Warning: adding jitter of 6.3241917655e-01
# Warning: adding jitter of 4.1473217255e-05
# Warning: adding jitter of 4.1473217255e-04
# Warning: adding jitter of 4.1473217255e-03
# Warning: adding jitter of 4.1473217255e-02
# Warning: adding jitter of 4.1473217255e-01
# Warning: adding jitter of 1.0175258788e-04
# Warning: adding jitter of 1.0175258788e-03
# Warning: adding jitter of 1.0175258788e-02
# Warning: adding jitter of 1.0175258788e-01
# Warning: adding jitter of 1.0175258788e+00
# Warning: adding jitter of 1.0361487762e-04
# Warning: adding jitter of 1.0361487762e-03
# Warning: adding jitter of 1.0361487762e-02
# Warning: adding jitter of 1.0361487762e-01
# Warning: adding jitter of 1.0361487762e+00
# Warning: adding jitter of 1.0267527559e-04
# Warning: adding jitter of 1.0267527559e-03
# Warning: adding jitter of 1.0267527559e-02
# Warning: adding jitter of 1.0267527559e-01
# Warning: adding jitter of 1.0267527559e+00
# Warning: adding jitter of 1.0409113958e-04
# Warning: adding jitter of 1.0409113958e-03
# Warning: adding jitter of 1.0409113958e-02
# Warning: adding jitter of 1.0409113958e-01
# Warning: adding jitter of 1.0409113958e+00
# Warning: adding jitter of 1.0337837082e-04
# Warning: adding jitter of 1.0337837082e-03
# Warning: adding jitter of 1.0337837082e-02
# Warning: adding jitter of 1.0337837082e-01
# Warning: adding jitter of 1.0337837082e+00
# Warning: adding jitter of 1.0232730563e-04
# Warning: adding jitter of 1.0232730563e-03
# Warning: adding jitter of 1.0232730563e-02
# Warning: adding jitter of 1.0232730563e-01
# Warning: adding jitter of 1.0232730563e+00
# Warning: adding jitter of 1.0391203168e-04
# Warning: adding jitter of 1.0391203168e-03
# Warning: adding jitter of 1.0391203168e-02
# Warning: adding jitter of 1.0391203168e-01
# Warning: adding jitter of 1.0391203168e+00
# Warning: adding jitter of 1.0311358511e-04
# Warning: adding jitter of 1.0311358511e-03
# Warning: adding jitter of 1.0311358511e-02
# Warning: adding jitter of 1.0311358511e-01
# Warning: adding jitter of 1.0311358511e+00
# Warning: adding jitter of 1.0193865798e-04
# Warning: adding jitter of 1.0193865798e-03
# Warning: adding jitter of 1.0193865798e-02
# Warning: adding jitter of 1.0193865798e-01
# Warning: adding jitter of 1.0193865798e+00
# Warning: adding jitter of 1.0371126689e-04
# Warning: adding jitter of 1.0371126689e-03
# Warning: adding jitter of 1.0371126689e-02
# Warning: adding jitter of 1.0371126689e-01
# Warning: adding jitter of 1.0371126689e+00
# ('Time to optimize = ', 4.505861999999979)
# ('Optimized mean = ', [])
# ('Optimized covariance = ', [0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, 0.11959021795139627, -0.17418946011751069, -0.5789761247021967])
# ('Optimized liklihood = ', [-2.3086990132083165])
# ('Final negative log marginal likelihood = ', 479.639)
# ('Kernel Sparsity = ', 0.05704781704781705)
# ('Observation Sparsity = ', 0.96257796257796258)
# ('Initial negative log marginal likelihood = ', 603.483)
# Warning: adding jitter of 2.4437395864e-04
# Warning: adding jitter of 2.4437395864e-03
# Warning: adding jitter of 2.4437395864e-02
# Warning: adding jitter of 2.4437395864e-01
# Warning: adding jitter of 2.4437395864e+00
# Warning: adding jitter of 2.2236905610e-04
# Warning: adding jitter of 2.2236905610e-03
# Warning: adding jitter of 2.2236905610e-02
# Warning: adding jitter of 2.2236905610e-01
# Warning: adding jitter of 2.2236905610e+00
# Warning: adding jitter of 2.5678480523e-04
# Warning: adding jitter of 2.5678480523e-03
# Warning: adding jitter of 2.5678480523e-02
# Warning: adding jitter of 2.5678480523e-01
# Warning: adding jitter of 2.5678480523e+00
# Warning: adding jitter of 2.3853908719e-04
# Warning: adding jitter of 2.3853908719e-03
# Warning: adding jitter of 2.3853908719e-02
# Warning: adding jitter of 2.3853908719e-01
# Warning: adding jitter of 2.3853908719e+00
# Warning: adding jitter of 2.1496632401e-04
# Warning: adding jitter of 2.1496632401e-03
# Warning: adding jitter of 2.1496632401e-02
# Warning: adding jitter of 2.1496632401e-01
# Warning: adding jitter of 2.1496632401e+00
# Warning: adding jitter of 2.5201028449e-04
# Warning: adding jitter of 2.5201028449e-03
# Warning: adding jitter of 2.5201028449e-02
# Warning: adding jitter of 2.5201028449e-01
# Warning: adding jitter of 2.5201028449e+00
# Warning: adding jitter of 2.3224939009e-04
# Warning: adding jitter of 2.3224939009e-03
# Warning: adding jitter of 2.3224939009e-02
# Warning: adding jitter of 2.3224939009e-01
# Warning: adding jitter of 2.3224939009e+00
# Warning: adding jitter of 2.0712655354e-04
# Warning: adding jitter of 2.0712655354e-03
# Warning: adding jitter of 2.0712655354e-02
# Warning: adding jitter of 2.0712655354e-01
# Warning: adding jitter of 2.0712655354e+00
# Warning: adding jitter of 2.4681295373e-04
# Warning: adding jitter of 2.4681295373e-03
# Warning: adding jitter of 2.4681295373e-02
# Warning: adding jitter of 2.4681295373e-01
# Warning: adding jitter of 2.4681295373e+00
# Warning: adding jitter of 2.5885531396e-04
# Warning: adding jitter of 2.5885531396e-03
# Warning: adding jitter of 2.5885531396e-02
# Warning: adding jitter of 2.5885531396e-01
# Warning: adding jitter of 2.5885531396e+00
# Warning: adding jitter of 2.6088746332e-04
# Warning: adding jitter of 2.6088746332e-03
# Warning: adding jitter of 2.6088746332e-02
# Warning: adding jitter of 2.6088746332e-01
# Warning: adding jitter of 2.6088746332e+00
# Warning: adding jitter of 2.5986553150e-04
# Warning: adding jitter of 2.5986553150e-03
# Warning: adding jitter of 2.5986553150e-02
# Warning: adding jitter of 2.5986553150e-01
# Warning: adding jitter of 2.5986553150e+00
# Warning: adding jitter of 2.5835455178e-04
# Warning: adding jitter of 2.5835455178e-03
# Warning: adding jitter of 2.5835455178e-02
# Warning: adding jitter of 2.5835455178e-01
# Warning: adding jitter of 2.5835455178e+00
# Warning: adding jitter of 2.6063087400e-04
# Warning: adding jitter of 2.6063087400e-03
# Warning: adding jitter of 2.6063087400e-02
# Warning: adding jitter of 2.6063087400e-01
# Warning: adding jitter of 2.6063087400e+00
# Warning: adding jitter of 2.5948533514e-04
# Warning: adding jitter of 2.5948533514e-03
# Warning: adding jitter of 2.5948533514e-02
# Warning: adding jitter of 2.5948533514e-01
# Warning: adding jitter of 2.5948533514e+00
# Warning: adding jitter of 2.6120924297e-04
# Warning: adding jitter of 2.6120924297e-03
# Warning: adding jitter of 2.6120924297e-02
# Warning: adding jitter of 2.6120924297e-01
# Warning: adding jitter of 2.6120924297e+00
# Warning: adding jitter of 2.6034309440e-04
# Warning: adding jitter of 2.6034309440e-03
# Warning: adding jitter of 2.6034309440e-02
# Warning: adding jitter of 2.6034309440e-01
# Warning: adding jitter of 2.6034309440e+00
# Warning: adding jitter of 2.5905957353e-04
# Warning: adding jitter of 2.5905957353e-03
# Warning: adding jitter of 2.5905957353e-02
# Warning: adding jitter of 2.5905957353e-01
# Warning: adding jitter of 2.5905957353e+00
# Warning: adding jitter of 2.6099191440e-04
# Warning: adding jitter of 2.6099191440e-03
# Warning: adding jitter of 2.6099191440e-02
# Warning: adding jitter of 2.6099191440e-01
# Warning: adding jitter of 2.6099191440e+00
# ('Time to optimize = ', 5.236148000000071)
# ('Optimized mean = ', [])
# ('Optimized covariance = ', [0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, 0.06684257883560123, -0.03419900814987837, -0.15885188964341038])
# ('Optimized liklihood = ', [-2.304206931402868])
# ('Final negative log marginal likelihood = ', 539.009)
# ('Kernel Sparsity = ', 0.23717255717255717)
# ('Observation Sparsity = ', 0.96257796257796258)
# ('Initial negative log marginal likelihood = ', 638.363)
# ('Time to optimize = ', 20.475559999999973)
# ('Optimized mean = ', [])
# ('Optimized covariance = ', [1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 1.1053527054673449, 0.3498725576777033, -1.6723162335645274])
# ('Optimized liklihood = ', [-2.2891093806303875])
# ('Final negative log marginal likelihood = ', 226.534)
# ('Kernel Sparsity = ', 0.99326403326403323)
# ('Observation Sparsity = ', 0.96257796257796258)

# %%
DN, DD = data.shape
CA = []

var_ar = []

steps = 20
runs = 10

for i in xrange(runs):
    CC= []
    var_ = []
    for N in [420-x*16 for x in range(steps)]:
        p = np.random.permutation(DN)
        data = data[p,:]
        
        # Get all data (exclude the 4th column which is binary) except the last 50 points for training
        x  = np.concatenate((data[:-N,:4],data[:-N,5:-1]),axis=1)
        x = (x - np.mean(x,axis=0))/(np.std(x,axis=0)+1.e-16)
        # The function we will perform regression on:  Median Value of owner occupied homes
        y  = np.reshape(data[:-N,-1],(len(data[:-N,-1]),1))
        my = np.mean(y)
        sy = np.std(y)
        y = (y-np.mean(y))/(np.std(y)+1.e-16)
        y[np.abs(y)<0.025] = 0
        # Test on the last 50 points
        xs  = np.concatenate((data[-N:,:4],data[-N:,5:-1]),axis=1)
        xs = (xs - np.mean(xs,axis=0))/(np.std(xs,axis=0)+1.e-16)
        ys = np.reshape(data[-N:,-1],(N,1))
        ys = (ys-my)/(sy+1.e-16)
        N,D = x.shape

        #print 'Housing Dataset Dim:', N, 'by', D

        var_local = []
        M = []
        C = []

        for kernel_type in xrange(3):
            model = pyGPs.GPR()
            if kernel_type == 0:
                model.setPrior(kernel=kernel_mackay()+pyGPs.cov.Noise())
            elif kernel_type == 1:
                model.setPrior(kernel=kernel_storkey()+pyGPs.cov.Noise())
            else:
                model.setPrior(kernel=kernel_melkumyan()+pyGPs.cov.Noise())
            model.getPosterior(x, y)

            model.meanfunc.hyp = optHyp[kernel_type][0]
            model.covfunc.hyp = optHyp[kernel_type][1]
            model.likfunc.hyp = optHyp[kernel_type][2]

            ym, ys2, fm, fs2, lp = model.predict(xs)
            xa  = np.concatenate((data[:,:4],data[:,5:-1]),axis=1)
            xa = (xa - np.mean(xa,axis=0))/(np.std(xa,axis=0)+1.e-16)
            ya, ys2a, fma, fs2a, lpa = model.predict(xa)

            cy = np.abs(y).max()**-1
            ck = np.abs(model.covfunc.getCovMatrix(x, xs, mode='cross')).max()**-1
            sy = np.sum(y!=0)
            sk = np.sum(model.covfunc.getCovMatrix(x, xs, mode='cross')!=0)/(DN-N)
            sn = np.exp(model.covfunc.cov2.hyp[0]*2)
            var_local.append([cy, ck, sy, sk, sn])
            C.append([np.sqrt(sy*sk)/(sn*ck*cy)]/np.mean(ys2))
        CC.append(C)
        var_.append(var_local)
    CA.append(CC)
    var_ar.append(var_)

# %%
CA_ = np.array(CA)

CA__ = np.mean(CA_.reshape([runs, steps, 3]),0)
CA_s = np.std(CA_.reshape([runs, steps, 3]),0)

plt.figure(figsize=[15,6])
plt.title('Sample Variance')
plt.ylabel('Single Run Sample Variance')
plt.xlabel('# Observations')
plt.plot([420-x*16 for x in range(steps)], CA__[::-1,0],'b')
plt.plot([420-x*16 for x in range(steps)], CA__[::-1,1],'g')
plt.plot([420-x*16 for x in range(steps)], CA__[::-1,2],'r')
plt.fill_between([420-x*16 for x in range(steps)],CA__[::-1,0]+CA_s[::-1,0]*3,CA__[::-1,0]-CA_s[::-1,0]*3, facecolor= [0.,0.0,1.0,0.2],linewidths=0.0 )
plt.fill_between([420-x*16 for x in range(steps)],CA__[::-1,1]+CA_s[::-1,1]*3,CA__[::-1,1]-CA_s[::-1,1]*3, facecolor= [0.,1.0,0.0,0.2],linewidths=0.0 )
plt.fill_between([420-x*16 for x in range(steps)],CA__[::-1,2]+CA_s[::-1,2]*3,CA__[::-1,2]-CA_s[::-1,2]*3, facecolor= [1.,0.0,0.0,0.2],linewidths=0.0 )
plt.yscale('log')

# %%
var__ = np.mean(np.array(var_ar),0)[:,0,:]
var__.shape
plt.plot(var__[:,0], 'r') #cy
plt.plot(var__[:,1], 'g') #ck
plt.plot(var__[:,2], 'b') #sy
plt.plot(var__[:,3], 'c') #sk
plt.plot(var__[:,4], 'm') #sn
plt.yscale('log')
plt.title('MacKay Kernel')

plt.figure()
var__ = np.mean(np.array(var_ar),0)[:,1,:]
var__.shape
plt.plot(var__[:,0], 'r') #cy
plt.plot(var__[:,1], 'g') #ck
plt.plot(var__[:,2], 'b') #sy
plt.plot(var__[:,3], 'c') #sk
plt.plot(var__[:,4], 'm') #sn
plt.yscale('log')
plt.title('Storkey Kernel')

plt.figure()
var__ = np.mean(np.array(var_ar),0)[:,2,:]
var__.shape
plt.plot(var__[:,0], 'r') #cy
plt.plot(var__[:,1], 'g') #ck
plt.plot(var__[:,2], 'b') #sy
plt.plot(var__[:,3], 'c') #sk
plt.plot(var__[:,4], 'm') #sn
plt.yscale('log')
plt.title('Melkumyan Kernel')
